# %% [markdown]
# # 03 — Direct Chinese Evidence Synthesis
#
# This notebook will reconstruct the structured synthesis of five empirical studies of Chinese preschool or kindergarten personnel.
#
# **Scope**
# - four teacher studies;
# - one principal study;
# - descriptive total: 2,564 analyzed participants.
#
# No copyrighted full text will be reproduced in the repository.

# %%
from pathlib import Path
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

RANDOM_SEED = 42
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

DATA_DIR = PROJECT_ROOT / "data"
INPUT_DIR = PROJECT_ROOT / "inputs"
OUTPUT_DIR = PROJECT_ROOT / "outputs"
TABLE_DIR = OUTPUT_DIR / "tables"
FIGURE_DIR = OUTPUT_DIR / "figures"
DIAGNOSTIC_DIR = OUTPUT_DIR / "diagnostics"

for directory in [TABLE_DIR, FIGURE_DIR, DIAGNOSTIC_DIR]:
    directory.mkdir(parents=True, exist_ok=True)

print(f"Project root: {PROJECT_ROOT}")
print(f"Random seed: {RANDOM_SEED}")

# %% [markdown]
# ## 1. Expected study-level inputs

# %%
EVIDENCE_FILE = INPUT_DIR / "china_evidence_register" / "china_evidence_register.xlsx"
CROSSWALK_FILE = INPUT_DIR / "construct_crosswalk" / "construct_crosswalk.xlsx"
print(EVIDENCE_FILE)
print(CROSSWALK_FILE)

# %% [markdown]
# ## 2. Load and audit the evidence register

# %%
# TODO: Load the verified study-level extraction register.
# Confirm study count, sample values, construct labels, and citation identifiers.

# %% [markdown]
# ## 3. Map constructs to the 4C framework

# %%
# TODO: Apply the verified construct crosswalk:
# Competence, Confidence, Caution, Context.

# %% [markdown]
# ## 4. Generate study-level synthesis tables

# %%
# TODO: Generate machine-readable study characteristics,
# evidence mapping, and synthesis outputs.

# %% [markdown]
# ## 5. Export verified outputs

# %%
# TODO: Export tables used in the manuscript and Supplementary Material.
