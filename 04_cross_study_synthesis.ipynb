# %% [markdown]
# # 04 — Cross-Study Synthesis
#
# This notebook integrates verified outputs from the three independent evidence streams without pooling respondent records.
#
# **Integration level**
# - constructs;
# - effects;
# - profiles;
# - evidence convergence;
# - professional-development priorities.
#
# Cross-source profile mappings are conceptual analogies, not statistically equivalent latent classes.

# %%
from pathlib import Path
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

RANDOM_SEED = 42
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

DATA_DIR = PROJECT_ROOT / "data"
INPUT_DIR = PROJECT_ROOT / "inputs"
OUTPUT_DIR = PROJECT_ROOT / "outputs"
TABLE_DIR = OUTPUT_DIR / "tables"
FIGURE_DIR = OUTPUT_DIR / "figures"
DIAGNOSTIC_DIR = OUTPUT_DIR / "diagnostics"

for directory in [TABLE_DIR, FIGURE_DIR, DIAGNOSTIC_DIR]:
    directory.mkdir(parents=True, exist_ok=True)

print(f"Project root: {PROJECT_ROOT}")
print(f"Random seed: {RANDOM_SEED}")

# %% [markdown]
# ## 1. Load verified study-level outputs

# %%
# TODO: Load only non-identifying aggregate outputs generated by notebooks 01–03.

# %% [markdown]
# ## 2. Harmonize effects and evidence direction

# %%
# TODO: Construct the cross-study effect register and convergence matrix.

# %% [markdown]
# ## 3. Cross-source profile mapping

# %%
# TODO: Map profile archetypes conservatively and document interpretation boundaries.

# %% [markdown]
# ## 4. Priority ranking

# %%
# TODO: Reproduce evidence-convergence scoring and Borda rank aggregation.

# %% [markdown]
# ## 5. Sensitivity analysis

# %%
# TODO: Reproduce alternative weighting and ranking scenarios.

# %% [markdown]
# ## 6. Export final tables and figures

# %%
# TODO: Export manuscript, supplementary, and figure-source outputs.
